# %%
import pandas as pd

# %%
first = pd.read_csv(r'C:\Users\Janek\Otomoto.pl\Rawgolf.csv')
first
# Out:
#       Unnamed: 0            ID    Price Predict_Low Predict_High  \
# 0              0  6.077535e+09  11900.0      11 250       13 100
# 1              1  6.070865e+09  14500.0      11 450       13 300
# 2              2  6.076245e+09  81900.0         NaN          NaN
# 3              3  6.072484e+09  68900.0         NaN          NaN
# 4              4  6.072485e+09  69500.0         NaN          NaN
# ...          ...           ...      ...         ...          ...
# 4757        4757           NaN      NaN         NaN          NaN
# 4758        4758           NaN      NaN         NaN          NaN
# 4759        4759           NaN      NaN         NaN          NaN
# 4760        4760           NaN      NaN         NaN          NaN
# 4761        4761           NaN      NaN         NaN          NaN
#
#                                                Location        Oferta od  \
# 0                                                   NaN  Osoby prywatnej
# ...

# %%
second = pd.read_csv(r'C:\Users\Janek\Otomoto.pl\RawGolf2.csv')
first
# Out:
#       Unnamed: 0            ID    Price Predict_Low Predict_High  \
# 0              0  6.077535e+09  11900.0      11 250       13 100
# 1              1  6.070865e+09  14500.0      11 450       13 300
# 2              2  6.076245e+09  81900.0         NaN          NaN
# 3              3  6.072484e+09  68900.0         NaN          NaN
# 4              4  6.072485e+09  69500.0         NaN          NaN
# ...          ...           ...      ...         ...          ...
# 4757        4757           NaN      NaN         NaN          NaN
# 4758        4758           NaN      NaN         NaN          NaN
# 4759        4759           NaN      NaN         NaN          NaN
# 4760        4760           NaN      NaN         NaN          NaN
# 4761        4761           NaN      NaN         NaN          NaN
#
#                                                Location        Oferta od  \
# 0                                                   NaN  Osoby prywatnej
# ...

# %%
joined = pd.concat?

# %%
joined = pd.concat

# %%
joined = pd.concat([first,second],
                 join = 'outer',
                  ignore_index = True)
joined
# Out:
#       Unnamed: 0            ID    Price Predict_Low Predict_High  \
# 0              0  6.077535e+09  11900.0      11 250       13 100
# 1              1  6.070865e+09  14500.0      11 450       13 300
# 2              2  6.076245e+09  81900.0         NaN          NaN
# 3              3  6.072484e+09  68900.0         NaN          NaN
# 4              4  6.072485e+09  69500.0         NaN          NaN
# ...          ...           ...      ...         ...          ...
# 9468        4706  6.002450e+09      NaN         NaN          NaN
# 9469        4707  6.001729e+09      NaN         NaN          NaN
# 9470        4708  6.001729e+09      NaN         NaN          NaN
# 9471        4709  6.001723e+09      NaN         NaN          NaN
# 9472        4710  4.035604e+09      NaN         NaN          NaN
#
#                                                Location        Oferta od  \
# 0                                                   NaN  Osoby prywatnej
# ...

# %%
joined.to_csv(r'C:\Users\Janek\Otomoto.pl\merged_golf.csv')
